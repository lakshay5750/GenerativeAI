# %%
import os 
from dotenv import load_dotenv
load_dotenv()
gemini_api_key=os.getenv("GEMINI_API_KEY")
groq_api_key=os.getenv("GROQ_API_KEY")
hf_api_key=os.getenv("HF_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
# !pip install langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-4.2.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<2.0.0,>=1.56.0 (from langchain-google-genai)
#   Downloading google_genai-1.72.0-py3-none-any.whl.metadata (52 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.5 in E:\ananconda3\envs\generativeai\Lib\site-packages (from langchain-google-genai) (1.2.28)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from langchain-google-genai) (2.12.5)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.13.0)
# Collecting google-auth<3.0.0,>=2.48.1 (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai)
#   Downloading google_auth-2.49.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in E:\ananconda3\envs\generativeai\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in E:\ananconda3\envs\generativeai\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.33.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in E:\ananconda3\envs\generativeai\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in E:\ananconda3\envs\generativeai\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in E:\ananconda3\envs\generativeai\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.11)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai)
#   Downloading cryptography-46.0.7-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: certifi in E:\ananconda3\envs\generativeai\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in E:\ananconda3\envs\generativeai\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in E:\ananconda3\envs\generativeai\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in E:\ananconda3\envs\generativeai\Lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (0.7.26)
# Requirement already satisfied: packaging>=23.2.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in E:\ananconda3\envs\generativeai\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in E:\ananconda3\envs\generativeai\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in E:\ananconda3\envs\generativeai\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in E:\ananconda3\envs\generativeai\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in E:\ananconda3\envs\generativeai\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in E:\ananconda3\envs\generativeai\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in E:\ananconda3\envs\generativeai\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.6.3)
# Collecting cffi>=2.0.0 (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai)
#   Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai)
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai)
#   Downloading pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Downloading langchain_google_genai-4.2.1-py3-none-any.whl (66 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_genai-1.72.0-py3-none-any.whl (764 kB)
#    ---------------------------------------- 0.0/764.2 kB ? eta -:--:--
#    ---------------------------------------- 764.2/764.2 kB 6.4 MB/s  0:00:00
# Downloading google_auth-2.49.2-py3-none-any.whl (240 kB)
# Downloading cryptography-46.0.7-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --------------------- ------------------ 1.8/3.5 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 9.4 MB/s  0:00:00
# Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: filetype, pycparser, pyasn1, pyasn1-modules, cffi, cryptography, google-auth, google-genai, langchain-google-genai
#
#    ---------------------------------------- 0/9 [filetype]
#    ---- ----------------------------------- 1/9 [pycparser]
#    -------- ------------------------------- 2/9 [pyasn1]
#    -------- ------------------------------- 2/9 [pyasn1]
#    -------- ------------------------------- 2/9 [pyasn1]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ----------------- ---------------------- 4/9 [cffi]
#    ----------------- ---------------------- 4/9 [cffi]
#    ---------------------- ----------------- 5/9 [cryptography]
#    ---------------------- ----------------- 5/9 [cryptography]
#    ---------------------- ----------------- 5/9 [cryptography]
#    ---------------------- ----------------- 5/9 [cryptography]
#    ---------------------- ----------------- 5/9 [cryptography]
#    ---------------------- ----------------- 5/9 [cryptography]
#    -------------------------- ------------- 6/9 [google-auth]
#    -------------------------- ------------- 6/9 [google-auth]
#    -------------------------- ------------- 6/9 [google-auth]
#    -------------------------- ------------- 6/9 [google-auth]
#    -------------------------- ------------- 6/9 [google-auth]
#    -------------------------- ------------- 6/9 [google-auth]
#    -------------------------- ------------- 6/9 [google-auth]
#    -------------------------- ------------- 6/9 [google-auth]
#    -------------------------- ------------- 6/9 [google-auth]
#    -------------------------- ------------- 6/9 [google-auth]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ----------------------------------- ---- 8/9 [langchain-google-genai]
#    ---------------------------------------- 9/9 [langchain-google-genai]
#
# Successfully installed cffi-2.0.0 cryptography-46.0.7 filetype-1.2.0 google-auth-2.49.2 google-genai-1.72.0 langchain-google-genai-4.2.1 pyasn1-0.6.3 pyasn1-modules-0.4.2 pycparser-3.0

# %%
response=model.invoke("what is generative ai")
print(response)
# Out:
# content='Generative AI refers to a type of artificial intelligence that can **create new and original content**, rather than just analyzing or classifying existing data. It\'s about **generating** something novel, whether it\'s text, images, music, code, or even complex simulations.\n\nThink of it as AI that can **imagine and produce**.\n\nHere\'s a breakdown of the key aspects of generative AI:\n\n**Core Functionality: Creation**\n\n*   **Generating Novel Content:** This is the defining characteristic. Instead of just telling you what\'s in an image, it can *create* a new image. Instead of summarizing a document, it can *write* a new document.\n*   **Learning Patterns and Structures:** Generative AI models are trained on massive datasets of existing content. Through this training, they learn the underlying patterns, styles, and structures of that data. For example, a text-generating AI learns grammar, vocabulary, sentence construction, and even different writing styles. An image-generating AI learns about shapes, colors, textures, and how objects are typically composed.\n*   **Probabilistic Generation:** When generating content, these models don\'t just pick randomly. They use their learned patterns to predict the most probable next element (word, pixel, note, etc.) that fits the context and desired output. This allows for coherent and often remarkably realistic creations.\n\n**How it Works (Simplified):**\n\nMost generative AI models are based on complex neural network architectures, with some of the most prominent being:\n\n*   **Large Language Models (LLMs):** These are trained on vast amounts of text data and excel at understanding and generating human-like text. Examples include GPT-3, GPT-4, LaMDA, and Bard.\n*   **Diffusion Models:** These are highly effective for image generation. They work by starting with random noise and gradually "denoising" it, guided by a text prompt, to create a coherent image. Examples include DALL-E 2, Midjourney, and Stable Diffusion.\n*   **Generative Adversarial Networks (GANs):** These consist of two neural networks, a generator and a discriminator, that compete against each other. The generator tries to create realistic data, and the discriminator tries to distinguish between real and generated data. This competition drives the generator to produce increasingly convincing outputs.\n\n**Key Applications and Capabilities:**\n\nGenerative AI is rapidly transforming various fields. Here are some prominent examples:\n\n*   **Text Generation:**\n    *   Writing articles, stories, poems, scripts.\n    *   Drafting emails, reports, marketing copy.\n    *   Summarizing long documents.\n    *   Translating languages.\n    *   Answering questions and engaging in conversations (chatbots).\n    *   Generating code.\n*   **Image Generation:**\n    *   Creating original artwork and illustrations from text descriptions.\n    *   Generating photorealistic images.\n    *   Editing and manipulating existing images.\n    *   Designing logos and product concepts.\n*   **Music Generation:**\n    *   Composing melodies, harmonies, and full musical pieces.\n    *   Generating music in various styles.\n*   **Video Generation:**\n    *   Creating short video clips from text prompts.\n    *   Animating characters.\n*   **3D Model Generation:**\n    *   Creating 3D objects and environments.\n*   **Code Generation:**\n    *   Writing code snippets, functions, or even entire programs.\n    *   Debugging and refactoring code.\n*   **Synthetic Data Generation:**\n    *   Creating realistic datasets for training other AI models, especially when real-world data is scarce or sensitive.\n\n**Benefits of Generative AI:**\n\n*   **Increased Creativity and Innovation:** It can help humans overcome creative blocks and explore new ideas.\n*   **Enhanced Productivity:** Automating content creation tasks can save significant time and resources.\n*   **Personalization:** Generating tailored content for individual users.\n*   **Acc ...

# %%
response.content.split("\n")
# Out:
# ["Generative AI refers to a type of artificial intelligence that can **create new and original content**, rather than just analyzing or classifying existing data. It's about **generating** something novel, whether it's text, images, music, code, or even complex simulations.",
#  '',
#  'Think of it as AI that can **imagine and produce**.',
#  '',
#  "Here's a breakdown of the key aspects of generative AI:",
#  '',
#  '**Core Functionality: Creation**',
#  '',
#  "*   **Generating Novel Content:** This is the defining characteristic. Instead of just telling you what's in an image, it can *create* a new image. Instead of summarizing a document, it can *write* a new document.",
#  '*   **Learning Patterns and Structures:** Generative AI models are trained on massive datasets of existing content. Through this training, they learn the underlying patterns, styles, and structures of that data. For example, a text-generating AI learns grammar, vocabulary, sentence construction, and even different writing styles. An image-generating AI learns about shapes, colors, textures, and how objects are typically composed.',
#  "*   **Probabilistic Generation:** When generating content, these models don't just pick randomly. They use their learned patterns to predict the most probable next element (word, pixel, note, etc.) that fits the context and desired output. This allows for coherent and often remarkably realistic creations.",
#  '',
#  '**How it Works (Simplified):**',
#  '',
#  'Most generative AI models are based on complex neural network architectures, with some of the most prominent being:',
#  '',
#  '*   **Large Language Models (LLMs):** These are trained on vast amounts of text data and excel at understanding and generating human-like text. Examples include GPT-3, GPT-4, LaMDA, and Bard.',
#  '*   **Diffusion Models:** These are highly effective for image generation. They work by starting with random noise and gradually "denoising" it, guided by a text prompt, to create a coherent image. Examples include DALL-E 2, Midjourney, and Stable Diffusion.',
#  '*   **Generative Adversarial Networks (GANs):** These consist of two neural networks, a generator and a discriminator, that compete against each other. The generator tries to create realistic data, and the discriminator tries to distinguish between real and generated data. This competition drives the generator to produce increasingly convincing outputs.',
#  '',
#  '**Key Applications and Capabilities:**',
#  '',
#  'Generative AI is rapidly transforming various fields. Here are some prominent examples:',
#  '',
#  '*   **Text Generation:**',
#  '    *   Writing articles, stories, poems, scripts.',
#  '    *   Drafting emails, reports, marketing copy.',
#  '    *   Summarizing long documents.',
#  '    *   Translating languages.',
#  '    *   Answering questions and engaging in conversations (chatbots).',
#  '    *   Generating code.',
#  '*   **Image Generation:**',
#  '    *   Creating original artwork and illustrations from text descriptions.',
#  '    *   Generating photorealistic images.',
#  '    *   Editing and manipulating existing images.',
#  '    *   Designing logos and product concepts.',
#  '*   **Music Generation:**',
#  '    *   Composing melodies, harmonies, and full musical pieces.',
#  '    *   Generating music in various styles.',
#  '*   **Video Generation:**',
#  '    *   Creating short video clips from text prompts.',
#  '    *   Animating characters.',
#  '*   **3D Model Generation:**',
#  '    *   Creating 3D objects and environments.',
#  '*   **Code Generation:**',
#  '    *   Writing code snippets, functions, or even entire programs.',
#  '    *   Debugging and refactoring code.',
#  '*   **Synthetic Data Generation:**',
#  '    *   Creating realistic datasets for training other AI models, especially when real-world data is scarce or sensitive.',
#  '',
#  '**Benefits of Generative AI:**',
#  '',
#  '*   **Increased Creativity and Innovation:** It can help humans overcome creative blocks and explore new ideas.',
#  '*   **Enhanced Productivity:** Automating content creation tasks can save significant time and resources.',
#  '*   **Personalization:** Generating tailored content for individual users.',
#  '*   **Accessibility:** Making complex creative tasks more accessible to a wider audience.',
#  '*   **Problem Solving:** Exploring potential solutions and scenarios.',
#  '',
#  '**Challenges and Considerations:**',
#  '',
#  '*   **Accuracy and Factual Correctness:** Generative AI can sometimes produce inaccurate or nonsensical information ("hallucinations").',
#  '*   **Bias:** Models can inherit biases present in their training data, leading to unfair or discriminatory outputs.',
#  '*   **Ethical Concerns:** Issues around misinformation, deepfakes, copyright, and job displacement.',
#  '*   **Computational Resources:** Training and running these models require significant computing power.',
#  '*   **Control and Alignment:** Ensuring that generated content aligns with human intentions and values.',
#  '',
#  "In essence, generative AI is a powerful new paradigm in AI that empowers machines to become creators. Its potential is vast, and it's constantly evolving, promising to reshape how we interact with technology and create content in the future."]

# %%
groq_model=init_chat_model("groq:openai/gpt-oss-120b")

# %%
response=groq_model.invoke("what is machine learning")

# %%
response.content.split("\n")
# Out:
# ['**Machine learning (ML)** is a sub‑field of artificial intelligence (AI) that focuses on building systems that can **learn from data** and improve their performance on a task without being explicitly programmed for every possible situation.',
#  '',
#  '### Core Idea',
#  '- **Data → Model → Prediction/Decision**  ',
#  '  1. **Data** (examples, measurements, images, text, etc.) are collected.  ',
#  '  2. An **algorithm** processes the data to create a **model**—a mathematical representation of patterns in the data.  ',
#  '  3. The model is then used to make **predictions** or **decisions** on new, unseen data.  ',
#  '- The model’s parameters are adjusted automatically (trained) to minimize errors, usually through an optimization process.',
#  '',
#  '### Main Types of Machine Learning',
#  '',
#  '| Category | How it learns | Typical tasks | Example algorithms |',
#  '|----------|---------------|---------------|--------------------|',
#  '| **Supervised learning** | Learns from labeled examples (input‑output pairs). | Classification (spam vs. not spam), regression (predict house price). | Linear regression, logistic regression, support vector machines, decision trees, random forests, neural networks. |',
#  '| **Unsupervised learning** | Finds structure in unlabeled data. | Clustering (group customers), dimensionality reduction (visualizing high‑dimensional data). | K‑means, hierarchical clustering, DBSCAN, PCA, t‑SNE, autoencoders. |',
#  '| **Semi‑supervised learning** | Uses a small amount of labeled data plus lots of unlabeled data. | Improves performance when labeling is expensive. | Graph‑based methods, self‑training, consistency regularization. |',
#  '| **Reinforcement learning** | Learns by interacting with an environment and receiving reward signals. | Game playing, robotics, recommendation systems. | Q‑learning, Deep Q‑Network (DQN), policy gradients, Proximal Policy Optimization (PPO). |',
#  '| **Self‑supervised learning** | Generates its own supervisory signal from raw data. | Language modeling, vision pre‑training. | Masked language models (BERT), contrastive learning (SimCLR). |',
#  '| **Transfer learning** | Adapts a model trained on one task/domain to a different but related task. | Fine‑tuning a large language model for a specific chatbot. | Pre‑trained BERT, GPT, ResNet. |',
#  '',
#  '### Typical Workflow',
#  '',
#  '1. **Define the problem** (e.g., predict churn, detect objects).  ',
#  '2. **Collect and preprocess data** (cleaning, normalization, feature engineering).  ',
#  '3. **Choose a model/algorithm** appropriate for the task and data size.  ',
#  '4. **Split data** into training, validation, and test sets.  ',
#  '5. **Train** the model on the training set (adjust parameters).  ',
#  '6. **Validate** and tune hyper‑parameters (e.g., learning rate, regularization).  ',
#  '7. **Evaluate** performance on the test set using metrics like accuracy, F1‑score, RMSE, etc.  ',
#  '8. **Deploy** the model to production and monitor it for drift or degradation.',
#  '',
#  '### Why It Matters',
#  '',
#  '- **Automation**: Enables systems to perform tasks that would require explicit programming for every rule.',
#  '- **Scalability**: Handles massive, high‑dimensional data that humans can’t manually analyze.',
#  '- **Adaptability**: Models can be updated with new data to stay current (e.g., spam filters that learn new spam patterns).',
#  '',
#  '### Real‑World Examples',
#  '',
#  '- **Recommendation engines** (Netflix, Amazon) suggesting movies or products.  ',
#  '- **Speech recognition** (Siri, Google Assistant) transcribing spoken words.  ',
#  '- **Computer vision** (self‑driving cars detecting pedestrians, medical imaging diagnosing disease).  ',
#  '- **Natural language processing** (chatbots, language translation, sentiment analysis).  ',
#  '- **Fraud detection** (banks spotting anomalous transactions).  ',
#  '',
#  '### Key Challenges',
#  '',
#  '- **Data quality & bias**: Poor or biased data leads to unreliable or unfair models.  ',
#  '- **Overfitting vs. underfitting**: Balancing model complexity to generalize well.  ',
#  '- **Interpretability**: Understanding why a model makes a particular decision, especially for high‑stakes domains.  ',
#  '- **Computational resources**: Training large models (e.g., deep neural networks) can be expensive.  ',
#  '- **Ethical considerations**: Privacy, accountability, and societal impact must be addressed.',
#  '',
#  '### Quick Glossary',
#  '',
#  '- **Feature**: An individual measurable property or attribute used as input to the model.  ',
#  '- **Label**: The target output (e.g., class name, numeric value) in supervised learning.  ',
#  '- **Loss function**: Quantifies the error between predictions and true labels; the model tries to minimize it.  ',
#  '- **Gradient descent**: An optimization algorithm that updates model parameters in the direction that reduces loss.  ',
#  '- **Epoch**: One full pass through the entire training dataset.  ',
#  '- **Hyper‑parameter**: Settings that control the learning process (e.g., learning rate, number of layers).  ',
#  '',
#  '---',
#  '',
#  '**In a nutshell:** Machine learning builds algorithms that automatically discover patterns from data and use those patterns to make predictions or decisions, enabling computers to perform complex tasks without explicit, rule‑by‑rule programming.']
